# %%
#Importing Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, f1_score, mean_absolute_error, mean_squared_error

# %% [markdown]
# **Loading the Data**

# %%
dataset = pd.read_csv("score.csv")

# %% [markdown]
# **Analyzing the Data**

# %%
dataset.head(10)
# Out:
#    Hours  Scores
# 0    2.5      21
# 1    5.1      47
# 2    3.2      27
# 3    8.5      75
# 4    3.5      30
# 5    1.5      20
# 6    9.2      88
# 7    5.5      60
# 8    8.3      81
# 9    2.7      25

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Hours   25 non-null     float64
#  1   Scores  25 non-null     int64
# dtypes: float64(1), int64(1)
# memory usage: 528.0 bytes

# %%
dataset.describe()
# Out:
#            Hours     Scores
# count  25.000000  25.000000
# mean    5.012000  51.480000
# std     2.525094  25.286887
# min     1.100000  17.000000
# 25%     2.700000  30.000000
# 50%     4.800000  47.000000
# 75%     7.400000  75.000000
# max     9.200000  95.000000

# %%
dataset.isnull().sum()
# Out:
# Hours     0
# Scores    0
# dtype: int64

# %%
#Spliting the data
x=dataset.iloc[:,:-1].values
y=dataset.iloc[:,1:]

# %%
#Visualizing the data
plt.figure(figsize=(10, 5)),

plt.scatter(x, y, color = "green")
plt.plot(x, color = "blue", linestyle = "-", linewidth = 3)
plt.title("General Visualization")
plt.xlabel("Study Hours")
plt.ylabel("Scores")
plt.show()

# %%
'''plt.figure(figsize = (10, 5))

plt.bar(x, int(y), color = "purple", width = 0.3)
plt.title("Bar plot Visualization")
plt.xlabel("Hours")
plt.ylabel("Scores")
plt.show()'''
# Out:
# 'plt.figure(figsize = (10, 5))\n\nplt.bar(x, int(y), color = "purple", width = 0.3)\nplt.title("Bar plot Visualization")\nplt.xlabel("Hours")\nplt.ylabel("Scores")\nplt.show()'

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=15)

# %% [markdown]
# **Creating a Model**

# %%
model = LinearRegression()

model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)

y_pred
# Out:
# array([[27.66781944],
#        [40.45688147],
#        [34.55423746],
#        [53.2459435 ],
#        [93.58067759]])

# %%
plt.figure(figsize = (7, 5))

plt.scatter(x_test, y_test, color = "blue", label = "Actual")
plt.plot(x_test, y_pred, color = "purple", label = "predicted")
plt.title("Comparision")
plt.xlabel("Study Hours")
plt.ylabel("Marks")
plt.show()

# %%
yp = y_pred.tolist()
yt = y_test.values.tolist()
dataset = pd.DataFrame({'Actual':yt, 'Predicted':yp})
dataset
# Out:
#   Actual             Predicted
# 0   [30]   [27.66781944304815]
# 1   [35]  [40.456881471800536]
# 2   [27]   [34.55423745853021]
# 3   [47]  [53.245943500552926]
# 4   [88]   [93.58067759123355]

# %%
#Metrics
print("MAE: ", mean_absolute_error(y_test, y_pred))
print("MSE: ", mean_squared_error(y_test, y_pred))
print("R2_Score: ", r2_score(y_test, y_pred))
print("Model Accuracy: ", model.score(x_train, y_train))
# Out:
# MAE:  5.433984115813815
# MSE:  32.487779543352175
# R2_Score:  0.9350556142184708
# Model Accuracy:  0.953981575634516

# %%
prediction = model.predict([[6]])

prediction
# Out:
# array([[62.09990952]])
